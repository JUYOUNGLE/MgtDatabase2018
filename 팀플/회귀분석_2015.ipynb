# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
# import pydot
# %matplotlib inline

# 폰트 문제 해결하기
import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
data = pd.read_excel("ff.xlsx")
data.head()
# Out:
#    X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  Y1  Y2
# 0   4   4   4   4   4   4   3   4   3    3   4   4
# 1   4   4   4   4   4   4   4   4   4    4   4   4
# 2   4   4   4   4   4   4   4   4   3    3   4   4
# 3   4   4   4   4   4   4   4   3   4    3   4   3
# 4   4   4   4   4   4   4   4   4   3    3   4   4

# %%
data = data.dropna(axis=1) # axis =1 열을 기준으로 삭제
data.head()
# Out:
#    X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  Y1  Y2
# 0   4   4   4   4   4   4   3   4   3    3   4   4
# 1   4   4   4   4   4   4   4   4   4    4   4   4
# 2   4   4   4   4   4   4   4   4   3    3   4   4
# 3   4   4   4   4   4   4   4   3   4    3   4   3
# 4   4   4   4   4   4   4   4   4   3    3   4   4

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms

# %%
from sklearn import preprocessing
import pandas as pd

X=pd.DataFrame(data, columns=["X1","X2","X3","X4","X5","X6","X7","X8","X9","X10"])
Y=pd.DataFrame(data, columns=["Y1"])

# %%
# 만족도와 재방문의사 회귀분석
linear_regression = sm.OLS(Y, X) # (종속변수, 독립변수)

# OLS 회귀모형 피팅
result_data = linear_regression.fit()

# 회귀분석 결과 요약
print(result_data.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     Y1   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                 4.121e+04
# Date:                Sat, 09 Jun 2018   Prob (F-statistic):               0.00
# Time:                        16:40:07   Log-Likelihood:                -14606.
# No. Observations:               12882   AIC:                         2.923e+04
# Df Residuals:                   12872   BIC:                         2.931e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X1             0.1149      0.011     10.384      0.000       0.093       0.137
# X2             0.0807      0.011      7.242      0.000       0.059       0.102
# X3             0.1465      0.012     11.992      0.000       0.123       0.170
# X4             0.2407      0.010     24.220      0.000       0.221       0.260
# X5             0.0521      0.007      7.207      0.000       0.038       0.066
# X6             0.0871      0.009      9.857      0.000       0.070       0.104
# X7            -0.0044      0.007     -0.590      0.555      -0.019       0.010
# X8             0.0439      0.009      5.146      0.000       0.027       0.061
# X9             0.0123      0.010      1.271      0.204      -0.007       0.031
# X10            0.2040      0.012     16.476      0.000       0.180       0.228
# ==============================================================================
# Omnibus:                     1506.765   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2851.482
# Skew:                          -0.765   Prob(JB):                         0.00
# Kurtosis:                       4.724   Cond. No.                         28.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X=pd.DataFrame(data, columns=["X1","X2","X3","X4","X5","X6","X7","X8","X9","X10"])
Y=pd.DataFrame(data, columns=["Y2"])

# %%
# 만족도와 추천의사 회귀분석
linear_regression = sm.OLS(Y, X) # (종속변수, 독립변수)

# OLS 회귀모형 피팅
result_data = linear_regression.fit()

# 회귀분석 결과 요약
print(result_data.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     Y2   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 6.484e+04
# Date:                Sat, 09 Jun 2018   Prob (F-statistic):               0.00
# Time:                        16:40:38   Log-Likelihood:                -11854.
# No. Observations:               12882   AIC:                         2.373e+04
# Df Residuals:                   12872   BIC:                         2.380e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X1             0.1341      0.009     15.001      0.000       0.117       0.152
# X2             0.1127      0.009     12.525      0.000       0.095       0.130
# X3             0.1281      0.010     12.982      0.000       0.109       0.147
# X4             0.2192      0.008     27.306      0.000       0.203       0.235
# X5             0.0155      0.006      2.660      0.008       0.004       0.027
# X6             0.0870      0.007     12.189      0.000       0.073       0.101
# X7            -0.0326      0.006     -5.477      0.000      -0.044      -0.021
# X8             0.0537      0.007      7.789      0.000       0.040       0.067
# X9             0.0255      0.008      3.271      0.001       0.010       0.041
# X10            0.2506      0.010     25.062      0.000       0.231       0.270
# ==============================================================================
# Omnibus:                      802.935   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1385.765
# Skew:                          -0.483   Prob(JB):                    1.22e-301
# Kurtosis:                       4.283   Cond. No.                         28.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
